# %%
# !pip install pandas matplotlib
# Out:
# zsh:1: command not found: pip

# %%
# Out:
# Requirement already satisfied: pandas in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: matplotlib in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd


data1 = pd.read_csv('results_jdbc.csv',sep=';',header=None,names=['framework', 'method', 'time'])
data2 = pd.read_csv('results_jpa.csv',sep=';',header=None, names=['framework', 'method', 'time'])
data3 = pd.read_csv('results_mybatis.csv',sep=';',header=None, names=['framework', 'method', 'time'])

data = pd.concat([data1, data2, data3], ignore_index=True)

# Berechnen Sie den Durchschnitt der Aufrufzeit für jede Methode
average_times = data.groupby(['framework', 'method'])['time'].mean().reset_index()

import matplotlib.pyplot as plt

# Wählen Sie ein Framework aus, für das Sie die Daten anzeigen möchten
framework = 'jpa'

# Filtern Sie die Daten für dieses Framework
framework_data = average_times[average_times['framework'] == framework]

# Erstellen Sie einen Balkendiagramm
plt.figure(figsize=(10,6))
plt.bar(framework_data['method'], framework_data['time'])
plt.xlabel('Method')
plt.ylabel('Average Time')
plt.title(f'Average Time per Method for {framework}')
plt.xticks(rotation=45)
plt.show()

# %%
pip install seaborn matplotlib
pip install pandas matplotlib
# Out:
# Requirement already satisfied: seaborn in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: matplotlib in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: pandas>=0.23 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: scipy>=1.0 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/mikehayo/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data1 = pd.read_csv('results_jdbc.csv',sep=';',header=None,names=['framework', 'method', 'time'])
data2 = pd.read_csv('results_jpa.csv',sep=';',header=None, names=['framework', 'method', 'time'])
data3 = pd.read_csv('results_mybatis.csv',sep=';',header=None, names=['framework', 'method', 'time'])

data = pd.concat([data1, data2, data3], ignore_index=True)

# Berechnen Sie den Durchschnitt der Aufrufzeiten für jede Methode pro Framework
avg_times = data.groupby(['framework', 'method'])['time'].median().reset_index()

# Erstellen Sie ein Balkendiagramm mit seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='method', y='time', hue='framework', data=avg_times, palette='viridis')

# Beschriftungen und Titel hinzufügen
plt.xlabel('Method')
plt.ylabel('Average Time')
plt.title('Average Time per Method by Framework')
plt.xticks(rotation=45)
plt.legend(title='Framework')

# Diagramm anzeigen
plt.tight_layout()
plt.show()
